# %%
import module_face

# %%
a = module_face.face_recognition()
# Out:
# load_img, profile, export_csv

# %%
a.load_img()

# %%
a.profile()
# Out:
# /Users/anu/Desktop/face_recognition/module_face.py:24: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   age_series = pd.Series(name='age')
# /Users/anu/Desktop/face_recognition/module_face.py:25: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   gender_series = pd.Series(name='gender')
# ...
# Action: gender: 100%|██████████| 3/3 [00:02<00:00,  1.46it/s]
# True
# ...
# Action: gender: 100%|██████████| 3/3 [00:00<00:00,  4.15it/s]
# True
#           angry   disgust      fear  ...       neutral  age  gender
# 0  7.800105e-30  0.000000  0.000000  ...  2.494205e-11   31   Woman
# 1  3.640825e+00  0.000058  3.021958  ...  8.052461e+01   31   Woman
#
# [2 rows x 9 columns]

# %%
a.export_csv()
