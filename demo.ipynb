# %%
import module_face

# %%
a = module_face.face_recognition()
# Out:
# load_img, profile, export_csv

# %%
a.load_img()
# Out:
# ['./data/img/img1.jpeg', './data/img/img10.jpeg']

# %%
a.profile()
# Out:
# ...
# Action: gender: 100%|██████████| 3/3 [00:02<00:00,  1.37it/s]
# True
# ...
# Action: gender: 100%|██████████| 3/3 [00:00<00:00,  4.20it/s]
# True
#           angry   disgust      fear       happy           sad      surprise  \
# 0  7.800105e-30  0.000000  0.000000  100.000000  1.384038e-26  1.262867e-11
# 1  3.640825e+00  0.000058  3.021958    1.041287  1.173977e+01  3.149237e-02
#
#         neutral  age gender
# 0  2.494205e-11   31  Woman
# 1  8.052461e+01   31  Woman

# %%
a.export_csv()
