# %%
from kao import face_recognition

# %%
a = face_recognition.load_img()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = face_recognition.load_img()
#
# TypeError: load_img() missing 1 required positional argument: 'self'
