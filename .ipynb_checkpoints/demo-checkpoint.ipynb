# %%
from kao_prot import face_recognition

# %%
a = face_recognition()
# Out:
# create_dataframe　→load_img→profile→export

# %%
a.create_dataframe()

# %%
a.load_img()

# %%
a.profile()
# Out:
# ...
# Action: gender: 100%|██████████| 3/3 [00:00<00:00,  7.14it/s]
#                                    angry       disgust       fear     happy  \
# ./data/img/uchiba_san_005.jpg   0.019670  5.729780e-09  12.489329  5.380588
# ./data/img/uchiba_san_007.jpg  14.883250  1.477604e-03   6.223075  0.007955
# ./data/img/uchiba_san_056.jpg   0.000140  4.070606e-12   0.714314  0.063686
# ./data/img/uchiba_san_069.jpg  18.631025  3.964431e-03  50.143212  0.048363
#
#                                      sad  surprise    neutral  age gender
# ./data/img/uchiba_san_005.jpg   5.907437  3.667446  72.535533   32    Man
# ./data/img/uchiba_san_007.jpg  29.855421  0.008819  49.020004   24    Man
# ./data/img/uchiba_san_056.jpg   0.015060  0.000162  99.206638   31  Woman
# ./data/img/uchiba_san_069.jpg  16.305019  9.317424   5.550988   28    Man

# %%
a.export()
